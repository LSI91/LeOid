# %%
"""

https://www.codingfinance.com/post/2019-07-01-analyze-ff-factor-python/

"""
# Out:
# '\n\nhttps://www.codingfinance.com/post/2019-07-01-analyze-ff-factor-python/\n\n'

# %%
import numpy as np
import pandas as pd
import copy
import matplotlib.pyplot as plt
import cvxpy as cp
import sys
import warnings
import urllib.request
import zipfile
import seaborn as sns

from pypfopt.expected_returns import mean_historical_return, ema_historical_return
from pypfopt.risk_models import CovarianceShrinkage, risk_matrix
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import objective_functions
from pypfopt import plotting
from pypfopt import black_litterman, risk_models
from pypfopt.black_litterman import BlackLittermanModel

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel('test_3_AC.xlsx', skiprows=5, index_col=0,date_parser=True)
df_header = pd.read_excel('test_3_AC.xlsx', skiprows=2, index_col=0,date_parser=True)
df.columns = df_header.columns
df.dropna(inplace=True)
df=df.loc['2001-08-21':,:]
pd.to_datetime(df.index)
cov=df.cov()

# %%
"""
Define expected return and risk models
"""

mu = mean_historical_return(df)
S = CovarianceShrinkage(df).ledoit_wolf()
risk_free_rate = 0.02
Tgt_Ret = 0.05
Tgt_Vol = 0.042
    
ef = EfficientFrontier(mu, S, weight_bounds=(None, None))
ef.add_constraint(lambda w: w[0] >= 0.2)
ef.add_constraint(lambda w: w[2] == 0.15)
ef.add_constraint(lambda w: w[3] + w[4] <= 0.10)

fig, ax = plt.subplots()
plotting.plot_efficient_frontier(ef, ax=ax, show_assets=True)
plt.show()

# %%
"""
Plotting Variance Covariance Matrix
"""
plotting.plot_covariance(S, plot_correlation=True, show_tickers=False)

# %%
def plot_efficient_frontier_and_portfolios(mu, S, risk_free_rate, Tgt_Ret, Tgt_Vol):  
    # Optimize portfolio for maximal Sharpe ratio 
    ef = EfficientFrontier(mu, S, weight_bounds=(0,1))
    fig, ax = plt.subplots(figsize=(8,6))
    ef_max_sharpe = copy.deepcopy(ef)
    plotting.plot_efficient_frontier(ef, ax=ax, show_assets=False)
    
    # Find the max sharpe portfolio
    ef_max_sharpe = EfficientFrontier(mu, S, weight_bounds=(0,1))
    ef_max_sharpe.max_sharpe(risk_free_rate)
    ret_tangent, std_tangent, _ =   ef_max_sharpe.portfolio_performance(risk_free_rate)
    ax.scatter(std_tangent, ret_tangent, marker="*", s=100, c="r",     label="Max Sharpe")
    
    # Find the min vol portfolio
    ef_min_vol = EfficientFrontier(mu, S, weight_bounds=(0,1))
    ef_min_vol.min_volatility()
    ret_tangent, std_tangent, _ =   ef_min_vol.portfolio_performance()
    ax.scatter(std_tangent, ret_tangent, marker="+", s=100, c="b",     label="Min vol")
    
    # Find the target return portfolio
    ef_ret = EfficientFrontier(mu, S, weight_bounds=(0,1))
    ef_ret.efficient_return(Tgt_Ret)
    ret_tangent, std_tangent, _ =   ef_ret.portfolio_performance()
    ax.scatter(std_tangent, ret_tangent, marker="o", s=100, c="g",     label="Tgt return")
    
    # Find the tgt vol portfolio
    ef_tgt_vol = EfficientFrontier(mu, S, weight_bounds=(0,1))
    ef_tgt_vol.efficient_risk(Tgt_Vol)
    ret_tangent, std_tangent, _ =   ef_tgt_vol.portfolio_performance()
    ax.scatter(std_tangent, ret_tangent, marker="+", s=100, c="b",     label="Tgt vol")
    
    

# Generate random portfolios
    n_samples = 1000
    w = np.random.dirichlet(np.ones(ef.n_assets), n_samples)
    rets = w.dot(ef.expected_returns)
    stds = np.sqrt(np.diag(w @ ef.cov_matrix @ w.T))
    sharpes = rets / stds
    ax.scatter(stds, rets, marker=".", c=sharpes, cmap="viridis_r")
# Output
    ax.set_title("Efficient Frontier with Random Portfolios")
    ax.legend()
    plt.tight_layout()
    plt.show()
        
plot_efficient_frontier_and_portfolios(mu, S, risk_free_rate, Tgt_Ret, Tgt_Vol)

ef_max_sharpe = EfficientFrontier(mu, S, weight_bounds=(0,1))
w_sharpe = ef_max_sharpe.max_sharpe()
cleaned_weights_sharpe = ef_max_sharpe.clean_weights()
df_w = pd.DataFrame(cleaned_weights_sharpe, columns=cleaned_weights_sharpe.keys(), index=['Weights Sharpe'])

ef_min_vol = EfficientFrontier(mu, S, weight_bounds=(0,1))
w_vol = ef_min_vol.min_volatility()
cleaned_weights_vol = ef_min_vol.clean_weights()
df_min_vol = pd.DataFrame(cleaned_weights_vol, columns=cleaned_weights_vol.keys(), index=['Weights Min Vol'])

ef_ret = EfficientFrontier(mu, S, weight_bounds=(0,1))
w_ret = ef_ret.efficient_return(Tgt_Ret)
cleaned_weights_ret = ef_ret.clean_weights()
df_ret = pd.DataFrame(cleaned_weights_ret, columns=cleaned_weights_ret.keys(), index=['Weights Tgt Ret'])

ef_tgt_vol = EfficientFrontier(mu, S, weight_bounds=(0,1))
w_vol = ef_tgt_vol.efficient_risk(Tgt_Vol)
cleaned_weights_vol = ef_tgt_vol.clean_weights()
df_tgt_vol = pd.DataFrame(cleaned_weights_vol, columns=cleaned_weights_vol.keys(), index=['Weights Tgt Vol'])


df_w = pd.concat([df_w,df_min_vol,df_ret,df_tgt_vol])
df_w
# Out:
# Expected annual return: 5.1%
# Annual volatility: 3.0%
# Sharpe Ratio: 1.05
#                  S&P 500 Total Return  MSCI EUROPE NR  TOPIX INDEX (TOKYO)  \
# Weights Sharpe                0.01582             0.0                  0.0
# Weights Min Vol               0.00462             0.0                  0.0
# Weights Tgt Ret               0.01560             0.0                  0.0
# Weights Tgt Vol               0.01115             0.0                  0.0
#
#                  MSCI Daily TR Net Emergi  SMI GROSS TOTAL RETURN  \
# Weights Sharpe                        0.0                 0.00000
# Weights Min Vol                       0.0                 0.01066
# Weights Tgt Ret                       0.0                 0.00000
# Weights Tgt Vol                       0.0                 0.00000
#
#                  U.S. Treasury  Treasury  U.S. Aggregate  \
# Weights Sharpe         0.07925   0.08714             0.0
# Weights Min Vol        0.00000   0.09854             0.0
# ...

# %%
df_ret = df.pct_change().dropna()

# %%
plt.figure(figsize=(50, 20))
mask = np.triu(np.ones_like(df_ret.corr(), dtype='bool'))
ax = sns.heatmap(df_ret.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
ax.set_title('Portfolio Holdings Correlation Heatmap', fontdict={'fontsize':18}, pad=16)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.savefig('.jpg', dpi=300, bbox_inches='tight')

# %%
df_mkt_caps = pd.read_excel('test_3_AC.xlsx', sheet_name='MKT_CAP', skiprows=4, index_col=0,date_parser=True).loc['MKT Cap USD':].transpose()
df_mkt_caps['weights'] = df_mkt_caps['MKT Cap USD'].apply(lambda row: row / df_mkt_caps.sum())

# %%
df_mkt_caps
# Out:
#                                 MKT Cap USD   weights
# S&P 500 Total Return            33557791.36  0.261652
# MSCI EUROPE NR               8821515.116638  0.068782
# TOPIX INDEX (TOKYO)          2941568.117781  0.022936
# MSCI Daily TR Net Emergi         6594757.83  0.051420
# SMI GROSS TOTAL RETURN       1151016.849912  0.008975
# U.S. Treasury                   10031860.88  0.078219
# Treasury                     7115968.818028  0.055484
# U.S. Aggregate                  24763364.44  0.193082
# U.S. Corporate High Yield        1300563.45  0.010141
# Pan-Euro Aggregate          16071976.520852  0.125314
# Pan-European High Yield       428297.211412  0.003339
# EM Hard Currency Aggregate       2201854.97  0.017168
# LUMSTRUU Index                   6887353.36  0.053701
# SPLSTAUSAll Loans                   1400000  0.010916
# CMBS                              485475.91  0.003785
# BBG Commodity TR                    4500000  0.035087

# %%
delta = black_litterman.market_implied_risk_aversion(df)
delta
# Out:
# S&P 500 Total Return           1.966835
# MSCI EUROPE NR                 1.006634
# TOPIX INDEX (TOKYO)            0.552593
# MSCI Daily TR Net Emergi       2.209710
# SMI GROSS TOTAL RETURN         1.378578
# U.S. Treasury                  6.009439
# Treasury                       8.982162
# U.S. Aggregate                10.979475
# U.S. Corporate High Yield     16.542317
# Pan-Euro Aggregate             8.946139
# Pan-European High Yield       13.828254
# EM Hard Currency Aggregate    15.246184
# LUMSTRUU Index                14.864444
# SPLSTAUSAll Loans             21.836590
# CMBS                           5.873575
# BBG Commodity TR               0.489922
# dtype: float64

# %%
market_caps = df_mkt_caps['MKT Cap USD'].to_dict()
mcaps = pd.Series(market_caps)
mkt_weights = mcaps / mcaps.sum()
mkt_weights
# Out:
# S&P 500 Total Return          0.261652
# MSCI EUROPE NR                0.068782
# TOPIX INDEX (TOKYO)           0.022936
# MSCI Daily TR Net Emergi      0.051420
# SMI GROSS TOTAL RETURN        0.008975
# U.S. Treasury                 0.078219
# Treasury                      0.055484
# U.S. Aggregate                0.193082
# U.S. Corporate High Yield     0.010141
# Pan-Euro Aggregate            0.125314
# Pan-European High Yield       0.003339
# EM Hard Currency Aggregate    0.017168
# LUMSTRUU Index                0.053701
# SPLSTAUSAll Loans             0.010916
# CMBS                          0.003785
# BBG Commodity TR              0.035087
# dtype: float64

# %%
prior = black_litterman.market_implied_prior_returns(mcaps, delta, S)
prior
# Out:
# S&P 500 Total Return          0.043395
# MSCI EUROPE NR                0.029598
# TOPIX INDEX (TOKYO)           0.022532
# MSCI Daily TR Net Emergi      0.038362
# SMI GROSS TOTAL RETURN        0.030799
# U.S. Treasury                 0.017033
# Treasury                      0.021140
# U.S. Aggregate                0.019672
# U.S. Corporate High Yield     0.048034
# Pan-Euro Aggregate            0.021519
# Pan-European High Yield       0.037477
# EM Hard Currency Aggregate    0.042084
# LUMSTRUU Index                0.021766
# SPLSTAUSAll Loans             0.034532
# CMBS                          0.024348
# BBG Commodity TR              0.022136
# dtype: float64

# %%
"""
Calcul des Expected Return via Model
1) Fama French
2) XXX
3) YYY
"""
# Out:
# '\nCalcul des Expected Return via Model\n1) Fama French\n2) XXX\n3) YYY\n'

# %%
# Fama French de mes fesses - US

# %%
dick_csv_ret = {
    'ff_fact_ret_US': 'F-F_Research_Data_Factors_daily.csv',
    'ff_fact_ret_EU': 'Europe_3_Factors_Daily.csv',
    'ff_fact_ret_JPN': 'Japan_3_Factors_Daily.csv',
    'ff_fact_ret_AS': 'Asia_Pacific_ex_Japan_3_Factors_Daily.csv',
}

dick_csv_mom = {
    'mom_fact_ret_US': 'North_America_MOM_Factor_Daily.csv',
    'mom_fact_ret_EU': 'Europe_MOM_Factor_Daily.csv',
    'mom_fact_ret_JPN': 'Japan_MOM_Factor_Daily.csv',
    'mom_fact_ret_AS': 'Asia_Pacific_ex_Japan_MOM_Factor_Daily.csv'
}


for i,j in zip(dick_csv_ret,dick_csv_mom):
    print(i,j)
# Out:
# ff_fact_ret_US mom_fact_ret_US
# ff_fact_ret_EU mom_fact_ret_EU
# ff_fact_ret_JPN mom_fact_ret_JPN
# ff_fact_ret_AS mom_fact_ret_AS

# %%
def get_ff_ret(): 
    
    dick_URL = {
        'ff_url_US': "http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_Factors_daily_CSV.zip",
        'ff_url_US_Mom':"http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/North_America_Mom_Factor_Daily_CSV.zip",
        'ff_url_EU': "http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/Europe_3_Factors_Daily_CSV.zip",
        'ff_url_EU_Mom':"http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/Europe_Mom_Factor_Daily_CSV.zip",
        'ff_url_JPN': "http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/Japan_3_Factors_Daily_CSV.zip",
        'ff_url_JPN_Mom': "http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/Japan_Mom_Factor_Daily_CSV.zip",
        'ff_url_As': "http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/Asia_Pacific_ex_Japan_3_Factors_Daily_CSV.zip",
        'ff_url_AS_Mom': "http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/Asia_Pacific_ex_Japan_Mom_Factor_Daily_CSV.zip"
    }

    for i in dick_URL: 
        urllib.request.urlretrieve(url=dick_URL[i], filename=dick_URL[i].split('/')[-1])
        zip_file = zipfile.ZipFile(dick_URL[i].split('/')[-1], 'r')
        zip_file.extractall()
        zip_file.close()
    
    dick_csv_ret = {
        'ff_fact_ret_US': 'F-F_Research_Data_Factors_daily.csv',
        'ff_fact_ret_EU': 'Europe_3_Factors_Daily.csv',
        'ff_fact_ret_JPN': 'Japan_3_Factors_Daily.csv',
        'ff_fact_ret_AS': 'Asia_Pacific_ex_Japan_3_Factors_Daily.csv',
    }

    dick_csv_mom = {
        'mom_fact_ret_US': 'North_America_MOM_Factor_Daily.csv',
        'mom_fact_ret_EU': 'Europe_MOM_Factor_Daily.csv',
        'mom_fact_ret_JPN': 'Japan_MOM_Factor_Daily.csv',
        'mom_fact_ret_AS': 'Asia_Pacific_ex_Japan_MOM_Factor_Daily.csv'
    }

    
    for i in dick_csv_ret:
        ff_fact_ret = pd.read_csv(dick_csv_ret[i],skiprows=4,index_col=0,parse_dates=True).reset_index().iloc[:-1,:]
        ff_fact_ret['index'] = pd.to_datetime(ff_fact_ret['index'])
        dick_csv_ret[i] = ff_fact_ret

    # Extraction Momentum

   
    for i in dick_csv_mom:
        mom_fact_ret = pd.read_csv(dick_csv_mom[i],skiprows=6,index_col=0,parse_dates=True).reset_index().iloc[:-1,:]
        mom_fact_ret['index'] = pd.to_datetime(mom_fact_ret['index'])
        dick_csv_mom[i] = mom_fact_ret
        
    for i,j in zip(dick_csv_ret,dick_csv_mom):
        dick_csv_ret[i] = pd.merge(left=dick_csv_ret[i], right=dick_csv_mom[j], how='inner',on='index').set_index('index').reset_index()
        
    dick_index={
            'SPX':'S&P 500 Total Return',
            'M7EU':'MSCI EUROPE NR',
            'TPX':'TOPIX INDEX (TOKYO)',
            'NDUEEGF':'MSCI Daily TR Net Emergi'
           }
    dick_de_black = {}

    df_ret = df.pct_change().iloc[1:,:].reset_index()

    for a,b in zip(dick_index,csv_ret):
        dick_de_black[a] = pd.merge(left=df_ret[['Dates',dick_index[a]]], right=csv_ret[b], how='inner',left_on='Dates',right_on='index').set_index('index').reset_index().drop('index', axis=1)
    
    return dick_de_black

# %%
csv_ret = get_ff_ret()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [200], in <cell line: 1>()
# ----> 1 csv_ret = get_ff_ret()
#
# Input In [199], in get_ff_ret()
#      59 df_ret = df.pct_change().iloc[1:,:].reset_index()
#      61 for a,b in zip(dick_index,csv_ret):
# ---> 62     dick_de_black[a] = pd.merge(left=df_ret[['Dates',dick_index[a]]], right=csv_ret[b], how='inner',left_on='Dates',right_on='index').set_index('index').reset_index().drop('index', axis=1)
#      64 return dick_de_black
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# ...

# %%
csv_ret['SPX']
# Out:
#           Dates  S&P 500 Total Return  Mkt-RF   SMB   HML     RF   WML
# 0    2001-08-22              0.007033    0.71  0.30 -0.57  0.013 -0.89
# 1    2001-08-23             -0.002746   -0.31 -0.27 -0.14  0.013  0.27
# 2    2001-08-24              0.019667    1.84 -0.15 -0.69  0.013 -3.04
# 3    2001-08-27             -0.004823   -0.42  0.30 -0.44  0.013 -0.67
# 4    2001-08-28             -0.014993   -1.46  0.23  0.77  0.013  1.26
# ...         ...                   ...     ...   ...   ...    ...   ...
# 5220 2022-05-23              0.018676    1.74 -1.07  1.29  0.001  0.68
# 5221 2022-05-24             -0.008107   -1.23 -0.94  1.84  0.001  1.99
# 5222 2022-05-25              0.009467    1.22  0.78  0.21  0.001 -0.68
# 5223 2022-05-26              0.019920    2.18  0.20 -0.63  0.001 -0.87
# 5224 2022-05-27              0.024919    2.58  0.35 -1.30  0.001 -0.34
#
# [5225 rows x 7 columns]

# %%
dick_index={
            'SPX':'S&P 500 Total Return',
            'M7EU':'MSCI EUROPE NR',
            'TPX':'TOPIX INDEX (TOKYO)',
            'NDUEEGF':'MSCI Daily TR Net Emergi'
           }

# %%
df_ret = df.pct_change().iloc[1:,:].reset_index()
dick_de_black = {}

for a,b in zip(dick_index,csv_ret):
    dick_de_black[a] = pd.merge(left=df_ret[['Dates',dick_index[a]]], right=csv_ret[b], how='inner',left_on='Dates',right_on='index').set_index('index').reset_index().drop('index', axis=1)

# %%
dick_de_black['NDUEEGF']
# Out:
#           Dates  MSCI Daily TR Net Emergi  Mkt-RF   SMB   HML    RF   WML
# 0    2001-08-22                  0.003446   -0.38 -0.54 -0.06  0.01  0.73
# 1    2001-08-23                 -0.001053    0.45 -0.26 -0.08  0.01  0.31
# 2    2001-08-24                  0.001648    0.40 -0.35 -0.44  0.01  0.30
# 3    2001-08-27                  0.012293    0.27 -0.66  0.54  0.01 -0.59
# 4    2001-08-28                 -0.003261   -0.06  0.11 -0.38  0.01  0.70
# ...         ...                       ...     ...   ...   ...   ...   ...
# 5414 2022-05-24                 -0.015832   -0.62 -0.02  1.19  0.00  1.13
# 5415 2022-05-25                  0.002618    0.04 -0.41  0.47  0.00 -0.15
# 5416 2022-05-26                  0.003342   -0.07 -0.02  0.27  0.00  0.22
# 5417 2022-05-27                  0.019923    1.56 -0.66 -0.74  0.00 -0.32
# 5418 2022-05-30                  0.021082    1.29  0.26 -1.59  0.00 -0.30
#
# [5419 rows x 7 columns]

# %%
df_ret = df.pct_change().iloc[1:,:].reset_index()

for a,b in zip(dick_index,csv_ret):
    for i,j in zip(df_ret[['Dates',dick_index[a]]],csv_ret[b]):
        print(pd.merge(left=df_ret[['Dates',dick_index[a]]], right=csv_ret[b], how='inner',left_on='Dates',right_on='index').set_index('index').reset_index().drop('index', axis=1))
# Out:
#           Dates  S&P 500 Total Return  Mkt-RF   SMB   HML     RF   WML
# 0    2001-08-22              0.007033    0.71  0.30 -0.57  0.013 -0.89
# 1    2001-08-23             -0.002746   -0.31 -0.27 -0.14  0.013  0.27
# 2    2001-08-24              0.019667    1.84 -0.15 -0.69  0.013 -3.04
# 3    2001-08-27             -0.004823   -0.42  0.30 -0.44  0.013 -0.67
# 4    2001-08-28             -0.014993   -1.46  0.23  0.77  0.013  1.26
# ...         ...                   ...     ...   ...   ...    ...   ...
# 5220 2022-05-23              0.018676    1.74 -1.07  1.29  0.001  0.68
# 5221 2022-05-24             -0.008107   -1.23 -0.94  1.84  0.001  1.99
# 5222 2022-05-25              0.009467    1.22  0.78  0.21  0.001 -0.68
# 5223 2022-05-26              0.019920    2.18  0.20 -0.63  0.001 -0.87
# 5224 2022-05-27              0.024919    2.58  0.35 -1.30  0.001 -0.34
#
# [5225 rows x 7 columns]
#           Dates  S&P 500 Total Return  Mkt-RF   SMB   HML     RF   WML
# ...

# %%
df_reg_test = pd.merge(left=df_test, right=df_test_ff, how='inner',left_on='Dates',right_on='index').set_index('index').reset_index().drop('index', axis=1)

# %%
df_reg_test
# Out:
#           Dates  S&P 500 Total Return  Mkt-RF   SMB   HML     RF   WML
# 0    2001-08-22              0.007033    0.71  0.30 -0.57  0.013 -0.89
# 1    2001-08-23             -0.002746   -0.31 -0.27 -0.14  0.013  0.27
# 2    2001-08-24              0.019667    1.84 -0.15 -0.69  0.013 -3.04
# 3    2001-08-27             -0.004823   -0.42  0.30 -0.44  0.013 -0.67
# 4    2001-08-28             -0.014993   -1.46  0.23  0.77  0.013  1.26
# ...         ...                   ...     ...   ...   ...    ...   ...
# 5220 2022-05-23              0.018676    1.74 -1.07  1.29  0.001  0.68
# 5221 2022-05-24             -0.008107   -1.23 -0.94  1.84  0.001  1.99
# 5222 2022-05-25              0.009467    1.22  0.78  0.21  0.001 -0.68
# 5223 2022-05-26              0.019920    2.18  0.20 -0.63  0.001 -0.87
# 5224 2022-05-27              0.024919    2.58  0.35 -1.30  0.001 -0.34
#
# [5225 rows x 7 columns]

# %%
df_test_ff = csv_ret['ff_fact_ret_US']

# %%
#df_ret.head()

# %%
X = df_ret[['S&P 500 Total Return']]


y = ffm_fact_ret.set_index('index').loc['2001-08-22':].reset_index()

# %%
X=X.reset_index()

# %%
df_reg = pd.merge(left=X, right=y, how='inner',left_on='Dates',right_on='index').set_index('index').reset_index()

# %%
df_reg
# Out:
#           index      Dates  S&P 500 Total Return  Mkt-RF   SMB   HML     RF  \
# 0    2001-08-22 2001-08-22              0.007033    0.71  0.30 -0.57  0.013
# 1    2001-08-23 2001-08-23             -0.002746   -0.31 -0.27 -0.14  0.013
# 2    2001-08-24 2001-08-24              0.019667    1.84 -0.15 -0.69  0.013
# 3    2001-08-27 2001-08-27             -0.004823   -0.42  0.30 -0.44  0.013
# 4    2001-08-28 2001-08-28             -0.014993   -1.46  0.23  0.77  0.013
# ...         ...        ...                   ...     ...   ...   ...    ...
# 5220 2022-05-23 2022-05-23              0.018676    1.74 -1.07  1.29  0.001
# 5221 2022-05-24 2022-05-24             -0.008107   -1.23 -0.94  1.84  0.001
# 5222 2022-05-25 2022-05-25              0.009467    1.22  0.78  0.21  0.001
# 5223 2022-05-26 2022-05-26              0.019920    2.18  0.20 -0.63  0.001
# 5224 2022-05-27 2022-05-27              0.024919    2.58  0.35 -1.30  0.001
#
#        WML
# 0    -0.89
# 1     0.27
# 2    -3.04
# ...

# %%
X = df_reg[['S&P 500 Total Return']]
y = df_reg.iloc[:,3:]

# %%
X = X *100

# %%
#X['S&P 500 Total Return']

# %%
#http://erwan.marginalq.com/index_files/tea_files/Python%20application%202.html

xMkt_RF=df_reg['Mkt-RF']
xSMB=df_reg['SMB']
xHML=df_reg['HML']
xMom=df_reg['WML']

ySP=df_reg['S&P 500 Total Return']*100

mMkt_RF, b = np.polyfit(xMkt_RF, ySP, 1)
mSMB, b = np.polyfit(xSMB, ySP, 1)
mHML, b = np.polyfit(xHML, ySP, 1)
mMom, b = np.polyfit(xMom, ySP, 1)

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)
 
# Splitting the data into training and testing data
#regr = LinearRegression()
 
#regr.fit(X_train, y_train)
#y_train_pred = regr.predict(X_train)
#y_test_pred = regr.predict(X_test)

#train_score = r2_score(y_train, y_train_pred)

# %%
#X_test.shape

# %%
#y_test.shape

# %%
#model_ols = LinearRegression(fit_intercept=True)

#d_mod_ols = model_ols.fit(X,y)

#print("Model RSQ: ".format() + str(d_mod_ols.score(X,y)))

#print("Coefficients: ".format() + str(d_mod_ols.coef_))

# %%
#reg = LinearRegression().fit(X, y)
#y_pred = reg.predict(X)
#r2_score(y_pred, y)
#d_mod_ols.coef_
#Coef_Beta = pd.DataFrame(d_mod_ols.coef_.transpose(), columns = ['Mkt-RF','SMB','HML','RF','Mom'])

# %%
#Coef_Beta

# %%
mMkt_RF, b = np.polyfit(xMkt_RF, ySP, 1)
mSMB, b = np.polyfit(xSMB, ySP, 1)
mHML, b = np.polyfit(xHML, ySP, 1)
mMom, b = np.polyfit(xMom, ySP, 1)

# %%
b1 = mMkt_RF
b2 = mSMB
b3 = mHML
b4 = mMom

market_premium = df_reg['Mkt-RF'].mean()
size_premium = df_reg['SMB'].mean()
value_premium = df_reg['HML'].mean()
momentum = df_reg['WML'].mean()
Risk_Free = df_reg['RF'].mean()

Expected_Return_Final = b1*market_premium + b2*size_premium + b3*value_premium + b4*momentum + Risk_Free
#Expected_Return_Final

# %%
Expected_Return_Final_Annualized = ((1+Expected_Return_Final/100)**252-1)*100
Expected_Return_Final_Annualized
# Out:
# 10.083652397570543

# %%
# Fama French de mes fesses - EU

# %%
# Extraction FF3Factor 

ff_url =  "http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/Europe_3_Factors_Daily_CSV.zip"

urllib.request.urlretrieve(ff_url,'Europe_3_Factors_Daily.zip')
zip_file = zipfile.ZipFile('Europe_3_Factors_Daily.zip', 'r')

zip_file.extractall()
zip_file.close()

# Extraction Momentum

ff_url = "http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/Europe_Mom_Factor_Daily_CSV.zip"

urllib.request.urlretrieve(ff_url,'Europe_MOM_Factor_Daily.zip')
zip_file = zipfile.ZipFile('Europe_MOM_Factor_Daily.zip', 'r')

zip_file.extractall()
zip_file.close()

# %%
# Mise en forme

ff_fact_ret = pd.read_csv('Europe_3_Factors_Daily.csv',skiprows=6,index_col=0,parse_dates=True).reset_index().iloc[:-1,:]
ff_fact_ret['index'] = pd.to_datetime(ff_fact_ret['index'])

mom_fact_ret = pd.read_csv('Europe_MOM_Factor_Daily.csv',skiprows=6,index_col=0,parse_dates=True).reset_index().iloc[:-1,:]
mom_fact_ret['index'] = pd.to_datetime(mom_fact_ret['index'])

ffm_fact_ret = pd.merge(left=ff_fact_ret, right=mom_fact_ret, how='inner',on='index').set_index('index').reset_index()
df_ret = df.pct_change().iloc[1:,:]

X_EU = df_ret[['MSCI EUROPE NR']]
y_EU = ffm_fact_ret.set_index('index').loc['2001-08-22':].reset_index()

X_EU=X_EU.reset_index()
df_reg_EU = pd.merge(left=X_EU, right=y_EU, how='inner',left_on='Dates',right_on='index').set_index('index').reset_index()

X_EU = df_ret[['MSCI EUROPE NR']]
y_EU = df_reg_EU.iloc[:,3:]
X_EU = X_EU *100

# %%
#http://erwan.marginalq.com/index_files/tea_files/Python%20application%202.html

xMkt_RFEU=df_reg_EU['Mkt-RF']
xSMBEU=df_reg_EU['SMB']
xHMLEU=df_reg_EU['HML']
xWMLEU=df_reg_EU['WML']

yMSCIEU=df_reg_EU['MSCI EUROPE NR']*100

mMkt_RFEU, b = np.polyfit(xMkt_RFEU, yMSCIEU, 1)
mSMBEU, b = np.polyfit(xSMBEU, yMSCIEU, 1)
mHMLEU, b = np.polyfit(xHMLEU, yMSCIEU, 1)
mWMLEU, b = np.polyfit(xWMLEU, yMSCIEU, 1)


b1Eu = mMkt_RFEU
b2Eu = mSMBEU
b3Eu = mHMLEU
b4Eu = mWMLEU

market_premium_EU = df_reg_EU['Mkt-RF'].mean()
size_premium_EU = df_reg_EU['SMB'].mean()
value_premium_EU = df_reg_EU['HML'].mean()
momentum_EU = df_reg_EU['WML'].mean()
Risk_Free_EU = df_reg_EU['RF'].mean()

Expected_Return_Final_EU = b1Eu*market_premium_EU + b2Eu*size_premium_EU + b3Eu*value_premium_EU + b4Eu*momentum_EU + Risk_Free_EU

Expected_Return_Final_EU_Annualized = Expected_Return_Final_EU*252
Expected_Return_Final_EU_Annualized
# Out:
# 1.134508037134072

# %%
b1Eu
# Out:
# 0.8526263167438113

# %%
b2Eu
# Out:
# -1.5858764368180902

# %%
b3Eu
# Out:
# 0.5128187219443562

# %%
b4Eu
# Out:
# -0.6240972434096687

# %%
X_EU=X_EU.iloc[:5419,:]

# %%
model_ols = LinearRegression(fit_intercept=True)
d_mod_ols = model_ols.fit(X_EU,y_EU)


Coef_Beta = pd.DataFrame(d_mod_ols.coef_.transpose(), columns = ['Mkt-RF','SMB','HML','RF','WML'])

# %%
Coef_Beta
# Out:
#     Mkt-RF       SMB       HML        RF      WML
# 0  0.90576 -0.376648  0.084047 -0.000074 -0.27507

# %%
(1+(Coef_Beta.transpose()[0] @ [market_premium_EU, size_premium_EU, value_premium_EU, Risk_Free_EU, momentum_EU])/100)**252
# Out:
# 1.0393104141851734

# %%
Coef_Beta.transpose()[0]
# Out:
# Mkt-RF    0.905760
# SMB      -0.376648
# HML       0.084047
# RF       -0.000074
# WML      -0.275070
# Name: 0, dtype: float64

# %%
Coef_Beta['Mkt-RF'][0]
# Out:
# 0.905759898387708

# %%
Coef_Beta['SMB'][0]
# Out:
# -0.37664751581622025

# %%
Coef_Beta['SMB'][0]
